# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ast

# %%
ptm_df = pd.read_csv('Data/Conserved_ptms_best_loc.csv')
mod_residues_dic = []
for i in ptm_df.mod_residues_dic:
    d = ast.literal_eval(i)
    mod_residues_dic.append(d)
ptm_df.mod_residues_dic = mod_residues_dic
num_species = []
for index, row in ptm_df.iterrows():
    d = row['mod_residues_dic']
    species = 0
    for key in d:
        if len(d[key][0]) > species:
            species = len(d[key][0])
    num_species.append(species)
ptm_df['num_species'] = num_species
ptm_df = ptm_df.sort_values('num_species', ascending = False)
ptm_df = ptm_df[ptm_df.num_species >=5]
ptm_df
# Out:
#      Unnamed: 0  Gene             Modification  \
# 221         221  prfB                   Methyl
# 685         685   tuf                 Ammonium
# 343         343  rplL                 Carbamyl
# 218         218  prfA                   Methyl
# 690         690   tuf       Methyl:2H(3)13C(1)
# 696         696   tuf                 Carbamyl
# 95           95  dnaK                 Ammonium
# 503         503  rpsB             Ammonia-loss
# 699         699   tuf  Delta:H(4)C(2)O(-1)S(1)
# 136         136  fusA   Dihydroxyimidazolidine
# 137         137  fusA             Ethoxyformyl
# 689         689   tuf             Methyl:2H(3)
# 692         692   tuf                   Fluoro
# 135         135  fusA             Carboxyethyl
# 92           92  dnaK             Ammonia-loss
# 32           32  atpA                 Carbamyl
# 576         576  rpsJ                 Carbamyl
# 702         702   tuf            Cation:Mg[II]
# 698         698   tuf            Acetyl:13C(2)
# 670         670   tsf                 Carbamyl
# 632         632  sucC                 Carbamyl
# 360         360  rplL  Delta:H(4)C(2)O(-1)S(1)
# 719         719   tuf             Ammonia-loss
# 96           96  dnaK             Methyl:2H(3)
# 590         590  rpsL             Ammonia-loss
# 289         289  rplE  Delta:H(4)C(2)O(-1)S(1)
# 723         723   tuf    Label:2H(3)+Oxidation
# 714         714   tuf               Dehydrated
# 45           45  atpD                 Carbamyl
# 694         694   tuf                  Carboxy
# 713         713   tuf                   Methyl
# 700         700   tuf                Cation:Na
# 701         701   tuf               glyoxalAGE
# 578         578  rpsJ  Delta:H(4)C(2)O(-1)S(1)
# 574         574  rpsI             Ammonia-loss
# 580         580  rpsK                 Carbamyl
# 423         423  rplU             Ammonia-loss
# 97           97  dnaK           Cation:Fe[III]
# 125         125  fusA                 Carbamyl
# 262         262  rplB                Oxidation
# 636         636  sucC  Delta:H(4)C(2)O(-1)S(1)
# 433         433  rplW                 Carbamyl
# 646         646  sucD                 Carbamyl
# 476         476  rpoB             Ammonia-loss
# 616         616  rpsS             Ammonia-loss
# 370         370  rplL            Cation:Ca[II]
# 94           94  dnaK                 Carbamyl
# 268         268  rplC                 Carbamyl
# 246         246  rplA                 Carbamyl
# 726         726   tuf             Label:13C(4)
# 691         691   tuf                Oxidation
# 705         705   tuf            Cation:Ca[II]
# 565         565  rpsH                 Carbamyl
# 391         391  rplO                 Carbamyl
# 416         416  rplT                 Carbamyl
#
#                                       mod_residues_dic  num_species
# 221  {273: [{'Cupriavidus_necator', 'Rhodopseudomon...           13
# 685  {38: [{'Delftia_acidovorans', 'Cellulophaga_ba...           10
# 343  {8: [{'Cellvibrio_gilvus', 'Mycobacterium_smeg...           10
# 218  {244: [{'Citrobacter_freundii', 'Rhizobium_rad...            9
# 690  {105: [{'Rhodopseudomonas_palustris', 'Stigmat...            8
# 696  {21: [{'Delftia_acidovorans', 'Cellulophaga_ba...            8
# 95   {144: [{'Rhodopseudomonas_palustris', 'Sulfoba...            8
# 503  {42: [{'Rhodopseudomonas_palustris', 'Stigmate...            7
# 699  {38: [{'Rhodopseudomonas_palustris', 'Mycobact...            7
# 136  {74: [{'Cupriavidus_necator', 'Citrobacter_fre...            7
# 137  {74: [{'Cupriavidus_necator', 'Citrobacter_fre...            7
# 689  {38: [{'Delftia_acidovorans', 'Cellulophaga_ba...            7
# 692  {55: [{'Cellvibrio_gilvus', 'Sulfobacillus_the...            7
# 135  {74: [{'Cupriavidus_necator', 'Citrobacter_fre...            7
# 92   {61: [{'Sulfobacillus_thermosulfidooxidans', '...            7
# 32   {5: [{'Bacillus_subtilis', 'Paracoccus_denitri...            7
# 576  {9: [{'Cellvibrio_gilvus', 'Cellulophaga_balti...            7
# 702  {45: [{'Delftia_acidovorans', 'Cellulophaga_ba...            6
# 698  {38: [{'Rhodopseudomonas_palustris', 'Stigmate...            6
# 670  {12: [{'Mycobacterium_smegmatis', 'Chryseobact...            6
# 632  {62: [{'Rhodopseudomonas_palustris', 'Mycobact...            6
# 360  {9: [{'Delftia_acidovorans', 'Chryseobacterium...            6
# 719  {51: [{'Cellvibrio_gilvus', 'Cellulophaga_balt...            6
# 96   {144: [{'Rhodopseudomonas_palustris', 'Sulfoba...            6
# 590  {71: [{'Paracoccus_denitrificans', 'Cupriavidu...            5
# 289  {72: [{'Cellvibrio_gilvus', 'Chryseobacterium_...            5
# 723  {105: [{'Cellulophaga_baltica', 'Rhodopseudomo...            5
# 714  {76: [{'Stigmatella_aurantiaca', 'Citrobacter_...            5
# 45   {130: [{'Delftia_acidovorans', 'Cellulophaga_b...            5
# 694  {38: [{'Cellulophaga_baltica', 'Rhodopseudomon...            5
# 713  {68: [{'Bacillus_subtilis', 'Cellulophaga_balt...            5
# 700  {60: [{'Coprococcus_comes', 'Ruminococcus_gnav...            5
# 701  {60: [{'Coprococcus_comes', 'Ruminococcus_gnav...            5
# 578  {14: [{'Cellvibrio_gilvus', 'Cellulophaga_balt...            5
# 574  {82: [{'Cupriavidus_necator', 'Delftia_acidovo...            5
# 580  {73: [{'Paracoccus_denitrificans', 'Delftia_ac...            5
# 423  {42: [{'Bacillus_subtilis', 'Coprococcus_comes...            5
# 97   {143: [{'Paracoccus_denitrificans', 'Delftia_a...            5
# 125  {46: [{'Stigmatella_aurantiaca', 'Chryseobacte...            5
# 262  {207: [{'Coprococcus_comes', 'Ruminococcus_gna...            5
# 636  {31: [{'Delftia_acidovorans', 'Stigmatella_aur...            5
# 433  {18: [{'Paracoccus_denitrificans', 'Stigmatell...            5
# 646  {17: [{'Cellvibrio_gilvus', 'Delftia_acidovora...            5
# 476  {200: [{'Cellulophaga_baltica', 'Chryseobacter...            5
# 616  {53: [{'Citrobacter_freundii', 'Cupriavidus_ne...            5
# 370  {20: [{'Cupriavidus_necator', 'Coprococcus_com...            5
# 94   {73: [{'Paracoccus_denitrificans', 'Cellulopha...            5
# 268  {50: [{'Citrobacter_freundii', 'Mycobacterium_...            5
# 246  {18: [{'Paracoccus_denitrificans', 'Delftia_ac...            5
# 726  {108: [{'Cellvibrio_gilvus', 'Sulfobacillus_th...            5
# 691  {35: [{'Ruminococcus_gnavus', 'Sulfobacillus_t...            5
# 705  {63: [{'Coprococcus_comes', 'Mycobacterium_sme...            5
# 565  {2: [{'Bacillus_subtilis', 'Chryseobacterium_i...            5
# 391  {88: [{'Delftia_acidovorans', 'Citrobacter_fre...            5
# 416  {40: [{'Paracoccus_denitrificans', 'Rhodopseud...            5

# %%
g = sns.pairplot(ptm_df, diag_kind = 'bar', x = 'Gene', y = 'Modification', size = 'num_species')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-14fdf09edf73> in <module>
# ----> 1 g = sns.pairplot(ptm_df, diag_kind = 'bar', x = 'Gene', y = 'Modification', size = 'num_species')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: pairplot() got an unexpected keyword argument 'x'

# %%
fig, axes = plt.subplots(2,1, figsize = (15,20)
sns.countplot(ax = axes[0], data = ptm_df, y= 'Modification')
sns.scatterplot(ax = axes[1], data = ptm_df, y = 'Modification', x = 'Gene', size = 'num_species', hue = 'Modification')
current_handles, current_labels = plt.gca().get_legend_handles_labels()
del current_labels[0:23]
del current_handles[0:23]
plt.legend(current_handles, current_labels)
axes[0].set_ylabel('PTM')
axes[0].set_xlabel('Number of Proteins') 
axes[0].set_title('Conserved PTM Frequency')
axes[1].set_ylabel('PTM')
axes[1].set_title('PTM Distribution')
plt.savefig('Figures/Figure_3.png')
# Out:
#   File "<ipython-input-41-7a83b6dd206f>", line 2
#     sns.countplot(ax = axes[0], data = ptm_df, y= 'Modification')
#     ^
# SyntaxError: invalid syntax
